# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0,'C:\Users\Sean Violante\Documents\Projects\lendico\lib')
import dwh

# %%
pendings=pd.read_csv('C:\Users\Sean Violante\Documents\Projects\lendico\Projects\Pendings\data\loan_requests_cohort_pending.csv',sep=';')
# Out:
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py:1159: DtypeWarning: Columns (16,54,74,80,86,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
pendings.head(25).T
# Out:
#                                                                        0   \
# id_loan_request                                                        13
# loan_request_nr                                                 199328068
# event_date                                                     2014-09-15
# event_week                                                        2014_38
# event_month                                                       2014_09
# event_date_timestamp                                  2014-09-15 11:52:27
# user_type                                                    regular_user
# user_campaign                                                       other
# country                                                       Netherlands
# dwh_country_id                                                        128
# id_user                                                               496
# gender                                                                  f
# ...
